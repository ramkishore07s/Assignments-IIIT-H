# %%
from nltk.corpus import brown
import random
import operator

# %%
from TrigramLanguageModel import TrigramLanguageModel, null_tokenizer

# %%
START = '<s>'
STOP = '<st>'
TERMINAL_POS = 'TER'

# %% [markdown]
# ## Models for HMM
# * `Emission_model(<o1>, <q2>, <o2>) = P(o2 | o1, q2)`
# * `POS_model(<q1>, <q2>, <q3>) = P(q3 | q2, q1)`

# %%
POS_model = TrigramLanguageModel(null_tokenizer)
Emission_model = TrigramLanguageModel(null_tokenizer)
possible_tags = {}

# %%
train_ = len(brown.tagged_sents()) * 0.8
train = brown.tagged_sents()[0:int(train_)]
dev_ = brown.tagged_sents()[int(train_):]
dev = brown.tagged_sents()[int(train_):]

# %%
def fill_in(sentence): return [(START, TERMINAL_POS), (START, TERMINAL_POS)] + sentence + [(STOP, TERMINAL_POS)]

# %% [markdown]
# ## Trigram Hidden Markov Model

# %%
print(train[0])
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ('County', 'NN-TL'), ('Grand', 'JJ-TL'), ('Jury', 'NN-TL'), ('said', 'VBD'), ('Friday', 'NR'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'IN'), ("Atlanta's", 'NP$'), ('recent', 'JJ'), ('primary', 'NN'), ('election', 'NN'), ('produced', 'VBD'), ('``', '``'), ('no', 'AT'), ('evidence', 'NN'), ("''", "''"), ('that', 'CS'), ('any', 'DTI'), ('irregularities', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('.', '.')]

# %% [markdown]
# ** Building POS, Emission  models**

# %%
for sentence in train:
    sentence = fill_in(sentence)
    for i in range(2, len(sentence)): POS_model.update_tree([sentence[i-2][1], sentence[i-1][1], sentence[i][1]])
    for i in range(1, len(sentence)): Emission_model.update_tree([sentence[i-1][0], sentence[i][1], sentence[i][0]])
    for w, p in sentence:
        if w in possible_tags: 
            if p not in possible_tags[w]:
                possible_tags[w].append(p)
        else: possible_tags[w] = [p]

# %% [markdown]
# ## Viterbi

# %%
class Viterbi():
    def __init__(self, POS_model, Emission_model, possible_tags):
        self.Q_model = POS_model
        self.O_model = Emission_model
        self.Q = list(POS_model.tree.keys())
        self.states = None
        self.sentence = None
        self.observations = None
        self.__cache = {}
        self.Q_ = possible_tags
        
    def __call__(self, sentence):
        for word in sentence:
            if not word in self.Q_:
                self.Q_[word] = self.Q
        self.states = None
        self.sentence = None
        self.observations = None
        self.__cache = {}
        self.states = None
        self.observations = self.__fill_in(sentence)
        self.r()
        self.get_pos()
        
        return self.states
    
    def __fill_in(self, sentence):
        return [START, START] + sentence + [STOP]
    
    def __r(self, n, position):
        if position > 3: # for both n-1 and n-2
            qn = self.Q_[self.observations[position]][n]
            for q1 in self.Q_[self.observations[position-1]]:
                arr = []
                for q2 in self.Q_[self.observations[position-2]]:
                    cur_prob = self.Q_model.get_prob([q2, q1, qn])
                    cur_prob *= self.O_model.get_prob([self.observations[position-2], q1 , self.observations[position-1]])
                    cur_prob *= self.__cache[position-1][q1][q2]
                    arr.append(cur_prob)
                self.__cache_probs(position, qn, q1, max(arr))
                    
        else: # only for n-1, q1 and q0 are constants
            max_q = None
            max_prob = 0
            q3 = self.Q_[self.observations[position]][n]
            o1, o2 = self.observations[1:3]
            for q2 in self.Q_[self.observations[position - 1]]:
                cur_prob = self.Q_model.get_prob([TERMINAL_POS, q2, q3])
                cur_prob *= self.O_model.get_prob([o1, q2 , o2])
                cur_prob *= self.Q_model.get_prob([TERMINAL_POS, TERMINAL_POS, q2])
                self.__cache_probs(position, q3, q2, cur_prob)
#                print(self.__cache)
                
    def __cache_probs(self, position, cur_pos, cur_his, prob):
        # position, current pos, prev two pos, prob
        if position not in self.__cache: self.__cache[position] = {}
        if cur_pos not in self.__cache[position]: self.__cache[position][cur_pos] = {}
        if cur_his not in self.__cache[position][cur_pos]: self.__cache[position][cur_pos][cur_his] = prob
        
    def r(self):
        for position in range(3, len(self.observations)):
            for n in range(len(self.Q_[self.observations[position]])): #for each q for each position cache probability based on q-1 and q-2
                self.__r(n, position)
            
    def get_pos(self):
        a = self.__cache
        top = len(a) + 2
        cur = 'TER'
        states = []
        while(top > 2):
            max_k, max_v = None, -1
            for i in a[top][cur]:
                if a[top][cur][i] > max_v:
                    max_v = a[top][cur][i]
                    max_k = i
            states.append(max_k)
            cur = max_k
            top -= 1
        self.states =  ['TER', 'TER'] + states[::-1]

# %%
v = Viterbi(POS_model, Emission_model, possible_tags)

# %% [markdown]
# ### Testing on first 500 sentences from held-out Dev set

# %%
a = 0
b = 0
count = 0
for i in dev[0:500]:
    print(count, end='\r')
    count += 1
    sentence, tags = list(zip(*i))
    try:
        pred = v(list(sentence))[2:-1]
        for i, j in zip(pred, list(tags)):
            if i == j: a += 1
            b += 1
    except Exception as e:
        print(e)
# Out:
# 499

# %%
print('Held out accuracy on first 500 sentences: ' +  str(float(a)/b * 100 ) + '%')
# Out:
# Held out accuracy on first 500 sentences: 92.38488783943329%

# %% [markdown]
# ## Forward Procedure

# %%
class Forward():
    def __init__(self, POS_model, Emission_model, possible_tags):
        self.Q_model = POS_model
        self.O_model = Emission_model
        self.Q = list(POS_model.tree.keys())
        self.states = None
        self.observations = None
        self.__cache = {}
        self.sentence = None
        self.Q_ = possible_tags
        
    def __call__(self, sentence):
        for word in sentence:
            if not word in self.Q_:
                self.Q_[word] = self.Q
        self.observations = [START, START] + list(sentence) + [STOP]
        self.sentence = sentence
        self.p_ = []
        self.p()
        
        return self.get_prob()
    
    def cache_prob(self, q, q1, n, prob):
        if n not in self.__cache: self.__cache[n] = {}
        if q not in self.__cache[n]: self.__cache[n][q] = {}
        self.__cache[n][q][q1] = prob
        
    def get_prob(self):
        f = len(self.observations) - 1
        p = 0.0
        for i in self.__cache[f]:
            for j in self.__cache[f][i]:
                p += self.__cache[f][i][j]
        return p
        
    def __p(self, q, n):
        if n > 2:
            prob = 0.0
            for q1 in self.Q_[self.observations[n-1]]:
                for q2 in self.Q_[self.observations[n-2]]:
                    temp = self.Q_model.get_prob([q2, q1, q]) 
                    temp *= self.__cache[n-1][q1][q2] 
                    temp *= self.O_model.get_prob([self.observations[n-2], q1, self.observations[n-1]])
                    prob += temp
                self.cache_prob(q, q1, n, prob)
            
        else:
            for q1 in self.Q_[self.observations[n-1]]:
                temp = self.Q_model.get_prob([TERMINAL_POS, q1, q])
                temp *= self.O_model.get_prob([self.observations[n-2], q1, self.observations[n-1]])
                prob = temp
                self.cache_prob(q, q1, n, prob)
            
    def p(self):
        for n in range(2, len(self.observations)):
            for q in self.Q_[self.observations[n]]:
                self.__p(q, n)

# %%
f = Forward(POS_model, Emission_model, possible_tags)

# %%
avg_train_prob = 0
for i in train[0:500]:
    try: avg_train_prob += f(list(zip(*i))[0])
    except: pass
avg_train_prob /= 500.
print('Average train probability is:', avg_train_prob)
# Out:
# Average train probability is: 0.013157183104485501

# %% [markdown]
# **Avg probability for dev set is relatively low because dev set has some previously unseen words, for which the Emission probabilities and State Transition probabilities are very low**

# %%
avg_dev_prob = 0
for i in dev[0:500]:
    try: avg_dev_prob += f(list(zip(*i))[0])
    except: pass
avg_dev_prob /= 500.
print('Average dev probability is:', avg_dev_prob)
# Out:
# Average dev probability is: 0.00011150557999454281

# %% [markdown]
# ## Top 50 words emitted by each POS tag

# %%
POS = {}

# %%
for sentence in train:
    for word, pos in sentence:
        if pos not in POS: POS[pos] = {word: 1}
        elif word not in POS[pos]: POS[pos][word] = 1
        else: POS[pos][word] += 1

# %%
for p in POS:
    print(p,": ", list(zip(*sorted(POS[p].items(), key=operator.itemgetter(1), reverse=True)))[0][0:50])
# Out:
# PPS+BEZ-HL :  ("It's",)
# . :  ('.', ';', '?', '!', ':')
# PPSS+BER-NC :  ("we're",)
# NNS$-TL :  ("Women's", "People's", "States'", "Motors'", "Nations'", "Citizens'", "Queens'", "Ladies'", "Giants'", "Dealers'", "Children's", "Mothers'", "Artists'", "Juniors'", "Veterans'", "Policemen's", "Officers'", "Archbishops'", "Writers'", "Trustees'", "Portwatchers'", "Delegates'", "Raiders'", "Sportsmen's", "Ass'ns'", "Friends'", "Princes'", "Girls'", "Students'", "Rogues'", "Bros.'", "Guideposts'", "Handlers'", "Pirates'", "Manufacturers'", "Employers'", "Grizzlies'", "Braves'", "Bombers'", "Falcons'", "Times'", "Men's", "Peoples'")
# NRS :  ('Sundays', 'Fridays', 'Mondays', 'Saturdays', 'Wednesdays')
# FW-NNS :  ('al', 'cetera', 'voyageurs', 'corroborees', 'kolkhozes', 'contadini', 'rata', 'amici', 'circonscriptions', 'crus', 'al.', 'virtuosi', 'boites', 'filles', 'illusions', 'libellos', 'Einsatzkommandos', 'engages', 'Engages', 'lutihaw', 'coureurs', 'pains', 'banditos', 'culpas', 'Pacta', 'phis', 'haflis', 'Jahr', 'palazzi', 'vopos', 'papiers', 'dejeuners', 'Dogumenti', 'chevaux', 'negociants', 'tyrannis', 'augen', 'zorrillas', 'alia', 'wohaws', 'metis', 'alpha-beta-gammas', 'maria', 'ghazals', 'messieurs')
# FW-JJ-NC :  ('sterios', 'demographiques')
# AP+AP-NC :  ('many-much',)
# WPS+HVD :  ("who'd",)
# NR-HL :  ('downtown', 'Tuesday', 'tomorrow', 'home', 'south', 'Sunday', 'Saturday', 'today', 'west', 'Home')
# CS-TL :  ('After', 'as')
# NN-TL-HL :  ('Sec.', 'Governor', 'B', 'Island', 'Day', 'Corps', 'Club', 'Lemma', 'Peace', 'Week', 'Fort', 'Show', 'Dr.', 'Constitution', 'Road', 'River', 'Tobacco', 'Grove', 'Chapter', 'Test', 'Congressman', 'Association', 'Gulf', 'Fellowship', 'Publication', 'Street', 'Society', 'Mayor', 'Beat', 'University', 'Head', 'Rider', 'Church', 'Section', 'Commissioner', 'Jazz', 'Ballet', 'Basin', 'Death', 'Oak', 'Champion', 'Prairie', 'Water', 'Drive', 'Fig.', 'Coast', 'Museum', 'Recreation', 'Spec.', 'Registry')
# FW-IN+AT :  ('du', 'des')
# BE :  ('be', 'Be')
# HV-HL :  ('have',)
# TO-NC :  ('to',)
# FW-AT-TL :  ('La', 'la', 'Le', 'Die', 'El', 'Les', 'der', 'un', 'Las', 'das', 'Das')
# DT-TL :  ('This', 'That')
# CD-TL-HL :  ('1', '6', '8', '4', '7', '10', '9', '5', 'Three', '12')
# OD-TL :  ('First', 'Seventh', 'Fifth', 'Second', 'Third', '7th', 'Fourth', 'Sixth', 'Twentieth', 'Eighth', 'Ninth', 'Nineteenth', 'Eighteenth', 'Twenty-second', 'Seventeenth', 'Fifty-fifth', 'Eighty-seventh', 'Sixteenth', '17th', '16th', '14th', 'Tenth', 'Fifteenth', '78th', '29th', '83rd', '20th', '3rd', 'Seventy-fourth', 'nineteenth', '50th', '66th', '24th', '46th', 'Thirty-eighth', '6th', '2d', 'Thirty-fourth', 'Forty-third', '51st', '30th', '701st', 'Sixty-eighth', '52nd', '3', 'Forty-second', 'Thirty-ninth', '61st', 'Fourteenth', 'Fifty-ninth')
# VBG-TL :  ('Planning', 'Fighting', 'Founding', 'Acting', 'Flying', 'Living', 'Presiding', 'Waiting', 'Printing', 'Broadcasting', 'Consulting', 'Rocking', 'Manufacturing', 'Training', "Smilin'", 'Conquering', 'Processing', 'Sleeping', 'Computing', 'Nursing', 'Purchasing', 'Traveling', 'Warring', 'Zoning', 'Publishing', 'Brooding', 'Squatting', 'Operating', 'Peeping', 'Trading', 'Commanding', 'Ginning', 'Burning', 'Sporting', 'Contemplating', 'Looking', 'Merchandising', 'Gossiping', 'Curling', "Comin'", 'Speaking', 'Hatching', 'Handling', 'Pooling', 'Balkanizing', 'Mocking', 'Selling', 'Falling', 'Organizing', 'Milling')
# , :  (',', ':', '[', ']')
# FW-RB-TL :  (',', 'assai', 'Bas')
# ABN-TL :  ('All',)
# BEN :  ('been',)
# VBG :  ('going', 'making', 'following', 'living', 'working', 'coming', 'taking', 'getting', 'using', 'doing', 'trying', 'looking', 'growing', 'running', 'operating', 'moving', 'saying', 'giving', 'reading', 'writing', 'playing', 'planning', 'increasing', 'waiting', 'talking', 'leaving', 'training', 'existing', 'standing', 'beginning', 'leading', 'asking', 'continuing', 'carrying', 'starting', 'cutting', 'thinking', 'building', 'providing', 'opening', 'developing', 'seeing', 'sitting', 'becoming', 'showing', 'passing', 'rising', 'acting', 'keeping', 'containing')
# WRB+DO :  ('Howda',)
# DTX :  ('either', 'neither', 'Neither', 'Either', 'nether', 'ether')
# BEZ-NC :  ('is',)
# PN-HL :  ('somebody', 'Nothing')
# :-HL :  (':',)
# VBN :  ('made', 'used', 'given', 'done', 'taken', 'found', 'seen', 'known', 'called', 'said', 'shown', 'required', 'written', 'expected', 'set', 'left', 'come', 'gone', 'concerned', 'developed', 'held', 'needed', 'become', 'considered', 'based', 'involved', 'obtained', 'determined', 'lost', 'increased', 'brought', 'provided', 'established', 'designed', 'placed', 'born', 'put', 'limited', 'described', 'paid', 'related', 'received', 'told', 'interested', 'added', 'prepared', 'applied', 'heard', 'covered', 'followed')
# EX+BEZ :  ("there's", "There's")
# ABN-NC :  ('all',)
# HVZ* :  ("hasn't",)
# FW-VBG-TL :  ('obliterans',)
# HVG-HL :  ('having',)
# BER-TL :  ('Are',)
# FW-BE :  ('sit',)
# PPSS+BER :  ("you're", "they're", "You're", "we're", "They're", "We're")
# RBR-NC :  ('more',)
# BEDZ :  ('was', 'Was')
# NN-NC :  ('water', 'thing', 'luggage', 'home', 'linguist', 'leader', 'alienation', 'cat', 'idea', 'chimney', 'paper', 'moment', 'noise', 'camp', 'town', 'chair', 'conclusion', 'trip', 'hunger', 'number', 'man', 'work', 'neighborhood', 'aya', 'tragedy', 'technology', 'ova', 'delivery', 'hustler', 'poetry-and-jazz', 'consciousness', 'wedlock', 'experiment', 'capitalism', 'return', 'Success', 'positivism', 'seduction', 'Word', 'distance', 'mountain', 'boat', 'herd', 'charge', 'trial', 'reading', 'occurrence', 'form', 'failure', 'hoof')
# IN-NC :  ('to', 'on', 'without', 'at', 'with', 'by', 'for', 'of', 'up', 'in', 'On', 'than')
# NN :  ('time', 'Af', 'man', 'way', 'world', 'year', 'life', 'work', 'state', 'day', 'number', 'fact', 'part', 'course', 'system', 'school', 'place', 'program', 'group', 'use', 'point', 'business', 'order', 'water', 'case', 'area', 'power', 'development', 'end', 'interest', 'hand', 'form', 'problem', 'night', 'side', 'country', 'sense', 'house', 'example', 'family', 'action', 'war', 'law', 'room', 'head', 'history', 'government', 'period', 'information', 'matter')
# WDT-HL :  ('What', 'what', 'which')
# FW-VB-NC :  ('contendere', 'esse')
# NPS-NC :  ('Steiners', 'Gar-Dene')
# FW-AT+NN-TL :  ("L'Union", "l'Universite", "l'Assistance", "l'Independance", "l'Ange", "L'Institut", "l'activite", "l'identite", "L'Arcade", "L'orchestre")
# .-TL :  ('?',)
# FW-HV :  ('habe',)
# WRB-NC :  ('why', 'when', 'how', 'How')
# TO-HL :  ('to', 'To')
# FW-VBG :  ('Servanda', 'appellant', 'nolens', 'dicendi', 'seq.', 'volens')
# WDT+BEZ-TL :  ("What's",)
# HV+TO :  ('hafta',)
# PPL-TL :  ('Myself',)
# )-HL :  (')',)
# CC-TL :  ('and', '&', 'And', "'n'", 'or')
# HVG :  ('having', 'Having')
# BED* :  ("weren't", "Weren't")
# BED :  ('were', 'Were')
# *-HL :  ('not', 'Not')
# WRB+IN :  ("Why'n",)
# JJR-HL :  ('better', 'Higher', 'Younger', 'Healthier', 'larger', 'Clearer', 'Lower', 'higher', 'Easier', 'Wider', 'older', 'lighter', 'Greater', 'Better', 'greater')
# PN :  ('one', 'something', 'nothing', 'anything', 'everything', 'anyone', 'none', 'One', 'everyone', 'someone', 'everybody', 'Nothing', 'somebody', 'anybody', 'nobody', 'Everything', 'Nobody', 'Something', 'Everyone', 'None', 'Anyone', 'Someone', 'Anything', 'Everybody', 'Anybody', 'Somebody', 'nothin', 'naught', 'no-one', 'sompin')
# PPSS+BER-TL :  ("You're",)
# NRS-TL :  ('Souths',)
# PPS+BEZ :  ("It's", "it's", "he's", "He's", "she's", "She's", "'tis")
# MD-TL :  ('Must', 'Should', 'Shall', 'Can', 'May')
# BEM-NC :  ('am',)
# FW-NN-TL :  ('Comedie', 'Place', 'Vita', 'Rue', 'Krystallographie', 'Arte', 'Kulturbund', 'Ballet', 'Redoute', 'Force', 'Reine', 'Prix', 'Lumiere', 'Romanza', 'Conseil', 'Son', 'Musique', 'Pax', 'Pater', 'Cieca', 'Sacre', 'Systeme', 'Vallfart', 'Mare', 'Rondo', 'Chateau', 'Parti', 'Auberge', 'Tertre', 'Tour', 'methode', 'Missa', 'Muzyka', 'Amicam', 'Homo', 'Concorde', 'Monarque', 'Mater', 'Bestimmung', 'Orchestre', 'Inferno', 'annee', 'Recherche', 'Senium', 'Section', 'Erde', 'Musica', 'Cygne', 'Calimala', 'Domina')
# UH-TL :  ('Welcome', 'Toot', 'Hi', 'Rockabye', 'Hurray', 'Jeepers', 'Hurrah', 'Creepers', 'Hooray', 'Oh', 'Eh')
# CD$ :  ("1960's", "1961's")
# NN+BEZ :  ("kid's", "sky's", "water's", "camera's", "undersecretary's", "money's", "bastard's", "father's", "throat's", "Heat's")
# NN-HL :  ('editor', 'name', 'chemical', 'birth', 'no.', 'time', 'business', 'Proof', 'method', 'research', 'year', 'Introduction', 'tax', 'distribution', 'Issue', 'Use', 'property', 'Article', 'procedure', 'type', 'Caution', 'Criticality', 'state', 'shelter', 'nomenclature', 'Chapter', 'proclamation', 'policy', 'house', 'war', 'education', 'nature', 'beef', 'Student', 'Example', 'Format', 'self-help', 'work', 'questionnaire', 'case', 'assignment', 'order', 'Protection', 'strength', 'analysis', 'flux', 'god', 'Currency', 'material', 'long-term')
# FW-IN+AT-TL :  ('Du', 'Des', 'Della', 'aux', 'Zur', 'des')
# FW-PPL :  ('se', 'Se')
# BEN-TL :  ('Been',)
# TO :  ('to', 'To')
# FW-NN :  ('facto', 'corps', 'fille', 'esprit', 'pas', 'oyabun', 'route', 'chambre', 'pax-ordo', 'ordo', 'carne', 'patronne', 'secco', 'canto', 'jure', 'Nacht', 'chili', 'scrutin', 'mano', 'ruh', 'Paredon', 'lubra', 'tabula', 'intonaco', 'infinitum', 'ersatz', 'coup', 'kolkhoz', 'paredon', 'excellence', 'titre', 'negociant', 'sacrificium', 'koinonia', 'wei', 'specie', 'milord', 'bonheur', 'Dachshund', 'valeur', 'chien', 'dejeuner', 'realismo', 'favore', 'koan', 'boun', 'basileis', 'resistance', 'novo', 'fide')
# RP :  ('up', 'out', 'down', 'on', 'off', 'in', 'over', 'through', 'about', 'across', 'Over', 'Up', 'Out', 'Off', 'Down', 'after', 'In')
# DTI :  ('some', 'any', 'Some', 'Any', 'ani', 'enny', 'anye')
# JJT-NC :  ('silliest',)
# NN+IN :  ('buncha',)
# FW-NP :  ('Karshilama', 'Espanol', 'Dieu')
# NPS-TL :  ('Sox', 'Yankees', 'Ephesians', 'Indies', 'Englanders', 'Saxons', 'Whigs', 'Franciscans', 'Galatians', 'Indians', 'Americans', 'Toppers', 'Rockettes', 'Kelts', "725's", 'Hebrews', 'Smokies', 'Corinthians', 'Scots', 'Berliners', 'Catholics', 'Philippians', 'Yorkers', 'Bolsheviks', 'Romans', 'Mets', 'Parliamentarians', 'Carolinians', 'Colossians', 'Sophias', 'Meistersinger', 'Russians', 'Democrats', 'Sieux')
# RP+IN :  ("out'n",)
# FW-QL :  ('minus',)
# VB+VB-NC :  ('say-speak',)
# PPSS+HVD :  ("I'd", "you'd", "we'd", "they'd", "We'd", "You'd")
# PPSS+HV :  ("I've", "you've", "We've", "You've", "They've", "they've", "we've")
# FW-*-TL :  ('non',)
# FW-PPO :  ('me', 'lui', 'moi')
# DOD* :  ("didn't", "Didn't")
# BEDZ* :  ("wasn't", "Wasn't")
# AT-TL :  ('The', 'the', 'A', 'No', 'An', 'Every')
# HVD* :  ("hadn't",)
# NN+HVD-TL :  ("Pa'd",)
# FW-UH-NC :  ('sayonara',)
# RB+BEZ-NC :  ("there's",)
# FW-AT-HL :  ('Al',)
# DT+MD :  ("That'll",)
# WPS+BEZ :  ("Who's", "that's", "who's")
# HVD :  ('had', 'Had')
# :-TL :  (':',)
# CC-TL-HL :  ('And', 'and')
# VB-HL :  ('feed', 'Contact', 'file', 'love', 'help', 'keep', 'practice', 'move', 'build', 'extend', 'know', 'use', 'waste', 'measure', 'pay', 'sew', 'grow', 'get', 'attend', 'fear', 'solve', 'save', 'increase', 'insert', 'Start', 'grant', 'Enforce', 'summarize', 'Turn', 'sue', 'stand', 'accomplish', 'try', 'study', 'allocate', 'Note', 'weave', 'cut', 'remain', 'like', 'fit', 'Let', 'win', 'reveal', 'go', 'Issue', 'honor', 'glow', 'put', 'open')
# : :  (':',)
# HVN :  ('had', 'hadd')
# PPSS-HL :  ('we', 'We', 'they', 'I', 'you')
# DOZ :  ('does', 'Does')
# DTS :  ('these', 'those', 'These', 'Those', 'them', 'Them', 'thease', 'thees')
# FW-NR :  ("aujourd'hui",)
# DOD*-TL :  ("Didn't",)
# OD-HL :  ('first', 'second', 'eighth', '28th', '30th', 'Fourth')
# NR-NC :  ('Tuesday', 'home')
# NR-TL :  ('South', 'West', 'North', 'East', 'Sunday', 'Southwest', 'Northeast', 'Friday', 'Northwest', 'Home', 'Tuesday', 'Today', 'Thursday', 'Southeast', 'Saturday')
# DOD :  ('did', 'Did', 'done')
# FW-DT+BEZ :  ("C'est",)
# FW-JJT :  ('optimo',)
# NN$-TL :  ("President's", "State's", "Department's", "Foundation's", "Government's", "King's", "Island's", "Year's", "Company's", "Man's", "Court's", "Earth's", "Secretary's", "Nation's", "Poet's", "Army's", "Governor's", "Navy's", "Church's", "University's", "Childhood's", "Council's", "Mayor's", "League's", "World's", "Pa's", "Authority's", "Gallery's", "Czarina's", "Star's", "Prince's", "Speaker's", "Administration's", "Division's", "Central's", "Justice's", "Harbor's", "Communism's", "General's", "Chief's", "Mama's", "Club's", "Woman's", "Time's", "Palace's", "Attorney's", "Collector's", "Sea's", "Tribune's", "Instructor's")
# UH-NC :  ('Hurrah', 'Fiddlesticks', 'hello', 'farewell')
# FW-NN$ :  ('curiae', 'senioritatis', "patronne's", "chambre's", 'corporis', 'intellectus', 'aeternitatis')
# PN-TL :  ('Nothing', 'Anything', 'Something')
# FW-IN+NN-TL :  ("D'Art", "D'Argent")
# WDT-NC :  ('what', 'which')
# NN-TL :  ('President', 'State', 'House', 'Dr.', 'Department', 'War', 'Secretary', 'Government', 'Island', 'City', 'University', 'Church', 'Act', 'Court', 'Union', 'Soviet', 'St.', 'World', 'College', 'General', 'Street', 'Committee', 'Association', 'River', 'County', 'Corps', 'Commission', 'Council', 'Army', 'Company', 'School', 'Club', 'Communist', 'Board', 'Service', 'Peace', 'Administration', 'Senate', 'District', 'Fig.', 'Lord', 'No.', 'Table', 'King', 'Co.', 'Section', 'Institute', 'Park', 'Defense', 'Hotel')
# RP-NC :  ('out', 'in', 'up')
# VB+JJ-NC :  ('die-dead',)
# MD-HL :  ('will', 'must', 'should', 'would', 'may', 'Must', 'could', 'can', 'might', 'Would', 'Could')
# PPSS-TL :  ('We', 'You', 'They')
# PPSS+HV-TL :  ("You've",)
# JJS-HL :  ('Top',)
# EX-NC :  ('there',)
# FW-PP$-NC :  ('mea',)
# VBZ-NC :  ('snows', 'stimulates', 'reads')
# CC :  ('and', 'or', 'but', 'But', 'And', 'either', 'nor', 'Yet', 'neither', 'Or', '&', 'yet', 'plus', 'Nor', 'and/or', 'Neither', 'Either', 'minus', 'butt', 'though', "'n'")
# NP+HVZ-NC :  ("Bill's",)
# DTS-HL :  ('those', 'These')
# *-TL :  ('Not',)
# JJ$-TL :  ("Great's",)
# VBD :  ('said', 'came', 'made', 'went', 'took', 'knew', 'began', 'gave', 'became', 'got', 'saw', 'found', 'told', 'seemed', 'asked', 'felt', 'thought', 'looked', 'wrote', 'turned', 'wanted', 'stood', 'called', 'left', 'showed', 'used', 'put', 'appeared', 'moved', 'brought', 'held', 'decided', 'tried', 'ran', 'walked', 'started', 'heard', 'kept', 'sat', 'led', 'continued', 'reached', 'opened', 'remained', 'added', 'happened', 'returned', 'stopped', 'passed', 'received')
# BEZ* :  ("isn't", "ain't", "Isn't", "Ain't", 'haint')
# JJS :  ('main', 'principal', 'top', 'chief', 'key', 'paramount', 'utmost', 'master', 'Chief', 'foremost', 'head', 'Top', 'tops', 'principle', 'uppermost', 'northernmost', 'innermost', 'Principal', 'Main')
# FW-NPS-TL :  ('Svenskarna',)
# DO* :  ("don't", "Don't")
# DOD-NC :  ('did',)
# HV :  ('have', 'Have', 'hast')
# EX :  ('there', 'There', 'ther', 'theare')
# PPS+HVZ :  ("He's", "She's", "he's", "it's", "It's", "she's")
# FW-CC :  ('et', 'Mais', 'und', 'mais', 'Y', 'Nec', 'aber')
# WQL-TL :  ('How',)
# FW-VBN :  ('vue', 'rasa', 'verstrichen', 'verboten')
# FW-NP-TL :  ('Afrique', 'Rundfunk')
# ABN :  ('all', 'half', 'All', 'many', 'Half', 'Many')
# PPS :  ('he', 'it', 'He', 'It', 'she', 'She', 'hytt', 'thee')
# WRB-HL :  ('How', 'where', 'Why', 'when', 'When', 'Where', 'how')
# IN :  ('of', 'in', 'to', 'for', 'with', 'on', 'by', 'at', 'from', 'In', 'into', 'about', 'through', 'over', 'between', 'under', 'against', 'than', 'after', 'without', 'For', 'during', 'upon', 'per', 'At', 'before', 'On', 'toward', 'out', 'within', 'among', 'around', 'With', 'across', 'By', 'along', 'including', 'behind', 'since', 'From', 'except', 'beyond', 'Of', 'above', 'up', 'During', 'After', 'near', 'down', 'To')
# BEM :  ('am', 'Am')
# PPL :  ('himself', 'itself', 'myself', 'herself', 'yourself', 'oneself', 'Himself', 'himselfe', 'hymselfe')
# NR :  ('today', 'home', 'Sunday', 'yesterday', 'Monday', 'Saturday', 'left', 'Friday', 'right', 'Tuesday', 'north', 'south', 'tomorrow', 'west', 'downtown', 'Today', 'east', 'Wednesday', 'Thursday', 'tonight', 'southeast', 'northwest', 'to-day', 'southwest', 'Tonight', 'West', 'northeast', 'Home', 'Tomorrow', 'North', 'Downtown', 'Yesterday', 'to-morrow')
# RBT :  ('best', 'most', 'highest', 'nearest', 'hardest', 'brightest', 'least', 'deepest', 'uppermost', 'fastest')
# BER* :  ("aren't", "ain't", "Aren't")
# AP :  ('other', 'more', 'many', 'same', 'few', 'last', 'much', 'most', 'only', 'several', 'least', 'little', 'next', 'less', 'single', 'enough', 'former', 'latter', 'Many', 'Most', 'certain', 'past', 'very', 'Other', 'various', 'More', 'Several', 'fewer', 'further', 'Last', 'Much', 'Few', 'particular', 'final', 'Next', 'individual', 'previous', 'Certain', 'Only', 'Enough', 'present', 'Little', 'Less', 'Further', 'Former', 'manye', 'lesser', 'Same', 'Past', 'plenty')
# FW-VBZ :  ('sigue', 'gouverne', 'sinkt')
# FW-VBD :  ('peccavi', 'audivi')
# CC-NC :  ('but', 'or', 'and')
# DO-TL :  ('Do',)
# FW-TO+VB :  ("d'entretenir",)
# FW-JJ :  ('bel', 'petits', 'haute', 'Gute', 'festivus', 'lange', 'continuo', 'juste', 'traditionnel', 'meme', 'vrai', 'sympathique', 'petit', 'colles', 'anticus', 'sanitaire', 'bona', 'avant', 'EUMMELIHS', 'firma', 'vermeil', 'chartaceos', 'tiefes', 'humaine', 'sana', 'salutaris', 'ipso', 'matinals', 'noire', 'Espagnol', 'bouffe', 'ostinato', 'merveilleux', 'formidable', 'viva', 'personnel', 'difficile')
# NR+MD :  ("today'll",)
# PPL-NC :  ('himself',)
# FW-PPS :  ('Il',)
# FW-WDT :  ('quo', 'qua', 'que', 'Quod')
# HVZ :  ('has', 'Has', 'hath')
# ABL :  ('such', 'Such', 'quite', 'rather', 'Quite')
# VBG+TO :  ('gonna', 'Gonna')
# DT-HL :  ('another', 'That', 'this', 'each', 'Another')
# UH :  ('Well', 'Oh', 'say', 'well', 'O', 'Bong', 'Jesus', 'amen', 'Okay', 'Amen', 'oh', 'Alas', 'alas', 'Hey', 'O.K.', 'Ah', 'eh', 'hey', 'huh', 'good-bye', 'Why', 'Hell', 'ah', 'Indeed', 'hell', 'hello', 'goodnight', 'bang', 'ha', 'goodbye', 'dammit', 'Dammit', 'Good-bye', 'Uh-huh', 'Eh', 'Hello', 'Goodbye', "'mon", 'hush', 'Haw', 'rum-tum-tum', 'Yooee', 'oops', 'Kaboom', 'sir', 'Bye', 'Toot', 'So', 'Bullshit', 'okay')
# JJ-TL-NC :  ('Utopian',)
# BEZ-TL :  ('Is',)
# WDT+HVZ :  ("what's", "What's")
# ,-NC :  (',',)
# CD-NC :  ('one',)
# PN+HVZ :  ("Somebody's", "Nobody's")
# DT$ :  ("another's",)
# VB+PPO :  ("Let's", "let's", 'Lemme')
# QL-NC :  ('very',)
# PPSS+MD-NC :  ("I'll",)
# CD-TL :  ('2', '1', '3', '4', '7', '5', '6', '12', 'Five', '8', 'Three', '104', '10', 'One', 'Four', '15', '13', '1040', 'Two', '9', '14', '18', 'Nineteen', '7-1', '50', '353', '99', 'Seven', '1040A', '31', '22', 'Six', '19', '23', '17', '24', '1960', '111', '32', '47', '7-2', '48', '348', '27', '500', '25', 'Eighty-Four', 'Eight', '114', '2.1')
# NIL :  (')', '(', '-', '38', 'and', 'the', 'in', 'a', 'to', 'into', 'made', 'of', 'on', 'his', 'an', 'year', 'he', '43*0C.', 'be', 'program', ':', 'ij', '--', 'threefold', 'calls', 'translate', '32*0C.', 'S.', 'entered', 'pamphlet', '71*&0C.', '60*0C.', 'after-school', 'obligations', 'neighborhood', 'their', '135*0C.', 'more', 'development', '29', 'LD', 'scale', 'before', 'commence', '49*0', 'can', 'Then', 'what-will-T.', 'Crisis', 'as')
# FW-BEZ :  ('est', 'ist')
# WDT+BEZ :  ("what's", "What's")
# FW-NNS-TL :  ('Revolutionibus', 'Crus', 'Forces', 'Artisans', 'Femmes', 'Amici', 'Sonates', 'Siecles', 'Affaires', 'Beaux-Arts', 'Planeten', 'Recherches', 'Notitia', 'Clericis', 'Vandringsar', 'Noces', 'Kristallstrukturen', 'Industrialistes', 'Commercants', 'Indigenes', 'Principia', 'Hovdingar', 'Maitres', 'Concerts', 'Putas', 'Variations', 'Laicos', 'Tabellen')
# NP :  ('Mr.', 'Mrs.', 'John', 'God', 'Miss', 'Washington', 'Kennedy', 'Congress', 'William', 'J.', 'America', 'Negro', 'A.', 'U.S.', 'Thomas', 'George', 'C.', 'England', 'June', 'May', 'James', 'Christ', 'Europe', 'March', 'E.', 'Robert', 'London', 'W.', 'Henry', 'S.', 'November', 'H.', 'France', 'Charles', 'April', 'Khrushchev', 'Jr.', 'Brown', 'B.', 'Russia', 'Hanover', 'D.', 'Laos', 'Virginia', 'Chicago', 'Mary', 'December', 'July', 'Germany', 'F.')
# DOZ-HL :  ('does',)
# FW-VB-TL :  ('Pati',)
# NPS :  ('Americans', 'Negroes', 'Jews', 'Democrats', 'Catholics', 'Russians', 'Republicans', 'Germans', 'Indians', 'Yankees', 'Belgians', 'French', 'Christians', 'Chinese', 'British', 'Protestants', 'Mexicans', 'Persians', 'Soviets', 'English', 'Orioles', 'Romans', 'Texans', 'Nazis', 'Englishmen', 'Scots', 'Japanese', 'Tories', 'Italians', 'Bourbons', 'Beardens', 'Minutemen', 'Dodgers', 'Cubans', 'Koreans', 'Turks', 'Indies', 'Swiss', 'Rebs', 'Greeks', 'Gospels', 'Quakers', 'Poles', 'Philippines', 'Yanks', 'Whigs', 'Chickasaws', 'Marches', 'Szolds', 'Saxons')
# MD* :  ('cannot', "can't", "couldn't", "won't", "wouldn't", "shouldn't", "Can't", "Wouldn't", "mustn't", "shan't", "Couldn't", "Won't")
# RB$ :  ("else's",)
# VB-NC :  ('go', 'tell', 'know', 'leave', 'deal', 'come', 'eat', 'trust', 'drink', 'sure', 'want', 'board', 'glorify', 'thank', "'nuff", 'get', 'say', 'cheat', 'keep')
# NPS$ :  ("Szolds'", "Birds'", "Coolidges'", "Redbirds'", "Beadles'", "Irelands'", "Christophers'", "Arabs'", "Wackers'", "Flannagans'", "Soviets'", "Adventists'", "Dresbachs'", "Yanks'", "Republicans'", "Achaeans'", "Krogers'", "Russians'", "Catholics'", "Albrights'", "Jews'", "Geraghtys'", "Negroes'", "Orioles'", "Yankees'", "Bucs'", "Burkes'", "Gershwins'", "Surcliffes'", "Stevenses'", "Indians'")
# FW-PN :  ('hoc',)
# NNS-TL :  ('States', 'Nations', 'Motors', 'Communists', 'Times', 'Juniors', 'Southerners', 'Affairs', 'Arts', 'Forces', 'Islands', 'Churches', 'Forests', 'Representatives', 'Police', 'Springs', 'Ages', 'Hills', 'Sons', 'Products', 'Heights', 'Friends', 'Trustees', 'Masters', 'Sixties', 'Plains', 'Figures', 'Blues', 'Publications', 'Services', 'Birds', 'Rules', 'Falls', 'Bears', 'Classes', 'Giants', 'Figs.', 'Relations', 'Fathers', 'Women', 'Banks', 'Presidents', 'Guideposts', 'Rights', 'Governments', 'Pirates', 'Gardens', 'Claims', 'Artists', 'Industries')
# VB+RP :  ("G'ahn",)
# EX-HL :  ('There',)
# FW-PPO+IN :  ('mecum', 'tecum')
# UH-HL :  ('Goodby',)
# HVZ-TL :  ('Has',)
# PPSS+MD :  ("I'll", "you'll", "I'd", "You'll", "We'll", "we'll", "you'd", "They'll", "they'd", "they'll", "we'd", "They'd", "We'd", "You'd")
# PP$-HL :  ('your', 'its', 'Our', 'our')
# NPS$-TL :  ("Yankees'",)
# AT :  ('the', 'a', 'The', 'an', 'no', 'A', 'every', 'No', 'An', 'Every')
# FW-* :  ('non', 'Non', 'Pas')
# VBD-HL :  ('served', 'Held', 'won', 'Faced', 'played', 'kept', 'brought', 'Led')
# WPO-NC :  ('that',)
# FW-JJR :  ('fortiori',)
# WRB+BEZ :  ("How's", "Where's")
# VB :  ('make', 'see', 'get', 'know', 'take', 'go', 'say', 'find', 'give', 'think', 'come', 'want', 'become', 'provide', 'seem', 'look', 'keep', 'let', 'use', 'show', 'believe', 'help', 'tell', 'like', 'work', 'leave', 'bring', 'feel', 'put', 'need', 'meet', 'mean', 'live', 'pay', 'hold', 'appear', 'include', 'call', 'turn', 'hear', 'move', 'consider', 'continue', 'understand', 'expect', 'run', 'serve', 'try', 'write', 'play')
# FW-OD-TL :  ('18e', '17e')
# BEG :  ('being', 'Being', "bein'", 'beinge', 'bein')
# PPSS+BEM :  ("I'm",)
# WPS :  ('who', 'that', 'Who', 'That', 'Whoever', 'whoever', 'whosoever', 'whoe')
# BEDZ-NC :  ('was',)
# PPS+BEZ-NC :  ("he's", "it's")
# JJR :  ('better', 'greater', 'higher', 'larger', 'lower', 'older', 'earlier', 'smaller', 'further', 'later', 'easier', 'longer', 'worse', 'stronger', 'younger', 'bigger', 'deeper', 'newer', 'lesser', 'broader', 'simpler', 'closer', 'shorter', 'heavier', 'wider', 'clearer', 'cheaper', 'upper', 'harder', 'happier', 'weaker', 'elder', 'tougher', 'slower', 'narrower', 'brighter', 'firmer', 'lighter', 'cooler', 'Further', 'louder', 'fuller', 'richer', 'taller', 'freer', 'warmer', 'quieter', 'faster', 'sounder', 'thicker')
# RP-TL :  ('Up', 'On')
# FW-WPS :  ('Qui',)
# PPLS :  ('themselves', 'ourselves', 'yourselves', "'emselves")
# EX+MD :  ("there'll", "There'll", "there'd")
# VBD-TL :  ('Got', 'Fingered', 'Lied', 'Broke', 'Ended', 'Married')
# NP$ :  ("God's", "Kennedy's", "Brown's", "America's", "Fromm's", "Pont's", "Hardy's", "Khrushchev's", "Russia's", "Plato's", "Pip's", "Steele's", "Trevelyan's", "Roberts'", "Eisenhower's", "Papa's", "Alex's", "Shakespeare's", "Mann's", "Hudson's", "O'Banion's", "Palfrey's", "Scotty's", "Georgia's", "Faulkner's", "Chicago's", "Ruth's", "Malraux's", "Garibaldi's", "John's", "Krim's", "Hetman's", "Rayburn's", "Sherman's", "Meeker's", "Bultmann's", "More's", "Washington's", "Shelley's", "Russell's", "Wright's", "Oersted's", "Mary's", "Aristotle's", "Wisman's", "Miller's", "Thomas'", "Eichmann's", "Christ's", "Killpath's")
# NNS-HL :  ('costs', 'methods', 'units', 'inches', 'Problems', 'Sources', 'policies', 'Properties', 'symbols', 'trials', 'Substances', 'measurements', 'constants', 'data', 'facilities', 'requirements', 'properties', 'Remarks', 'children', 'practices', 'Results', 'activities', 'needs', 'resources', 'considerations', 'Sheep', 'operations', 'years', 'cattle', 'studies', 'fabrics', 'returns', 'gains', 'plans', 'sales', 'states', 'Examples', 'materials', 'funds', 'adjustments', 'publications', 'foods', 'men', 'techniques', 'seams', 'samples', 'members', 'Facilities', 'allotments', 'frankfurters')
# RN :  ('then', 'afar', 'here', 'Then')
# ' :  ("'",)
# WDT+BEZ-HL :  ("What's",)
# HVD-HL :  ('had',)
# NNS$-TL-HL :  ("Women's",)
# BE-HL :  ('be',)
# JJT-HL :  ('best', 'Best', 'highest', 'Coolest', 'gravest')
# MD+HV :  ('coulda', 'musta', 'shouldda', "must've")
# CS :  ('that', 'as', 'than', 'if', 'like', 'If', 'because', 'As', 'while', 'for', 'so', 'before', 'though', 'until', 'since', 'whether', 'after', 'although', 'Since', 'Although', 'While', 'For', 'After', 'unless', 'Though', 'once', 'Like', 'Before', 'That', 'Because', 'So', 'whereas', 'Whether', 'till', 'Once', 'Until', 'lest', 'Unless', 'Whereas', 'whereupon', 'providing', 'altho', 'Than', "so's", 'albeit', 'then', 'supposing', 'Yff', 'Till', 'yff')
# '' :  ("''",)
# TO-TL :  ('To',)
# EX+HVZ :  ("there's",)
# MD*-HL :  ("Wouldn't",)
# HV-NC :  ('have',)
# VBZ-TL :  ('Comes', 'Means', 'Loses', 'Sez', 'Drifts', 'Objects', 'Resolves', 'Follows', 'Rises', 'Faces', 'Writes', 'Wakes', 'Cares', 'Stops', 'Meets')
# FW-IN+AT-T :  ('Des',)
# AP$ :  ("other's",)
# -- :  ('--',)
# IN-TL-HL :  ('Of', 'of')
# PPSS-NC :  ('I', 'you')
# QL-HL :  ('too', 'much', 'well', 'Naturally')
# FW-CD-TL :  ('Unam', 'Zwei')
# FW-NN-NC :  ('nisf-i-jahan', 'Strukturbericht', 'wohaw', 'ASPIS', 'SAKOS')
# BED-NC :  ('were',)
# NPS$-HL :  ("Democrats'",)
# FW-PP$-TL :  ('deras',)
# FW-AT :  ('la', 'le', 'die', 'ein', 'keine', 'Le', 'eine', 'Die')
# WDT+BER+PP :  ('whaddya',)
# FW-CD :  ('deux', 'sieben', 'une', 'cinq')
# VB+TO :  ('wanta', 'wanna')
# FW-IN-TL :  ('De', 'de', 'Von', 'Sans', 'Pro', 'pour', 'En', 'Sur', 'dans', 'avec', 'con', 'Auf', 'Pendant', 'auf', 'Ad', 'a')
# NNS-NC :  ('people', 'instructions', 'things', 'friends', 'sisters', 'relatives', 'emeralds', "tailin's", 'suggestions', 'women', 'lives')
# NP+HVZ :  ("Celie's", "Tim's", "Guardino's", "Crosson's", "Skolman's")
# NP-HL :  ('A', 'B', 'C', 'Washington', 'D', 'Inquirer', 'Aug.', 'Mr.', 'E', 'AP', 'March', 'John', 'God', 'Chicago', 'Jr.', 'Texas', 'A.', 'Notte', 'Austin', 'Feb.', 'F', 'June', 'Fla.', 'May', 'UPI', 'U.S.', 'Jan.', 'Miami', 'St.', 'G', 'Midwest', 'Moscow', 'Cuba', 'Annapolis', 'Price', 'Oct.', 'J', 'Monagan', 'April', 'Sam', 'Harvey', 'Christ', 'Ohio', 'Mrs.', 'Lauderdale', 'London', 'Lo', 'Shu', 'July', 'U.N.')
# ( :  ('(', '[')
# PPO :  ('it', 'him', 'them', 'me', 'her', 'us', 'you', 'Him', "'em", 'thee', "'im", 'mee', 'em', 'Me', 'hym', 'ya', 'u', 'Thee', 'Her', 'um', 'thum', "we'uns")
# CC-HL :  ('and', 'or', 'but', '&', 'And')
# FW-IN :  ('de', 'De', 'en', 'ad', 'par', 'a', 'con', 'sine', 'ex', 'sur', 'post', 'sub', 'per', 'A', 'inter', 'super')
# BEDZ-HL :  ('was',)
# NNS-TL-NC :  ('States',)
# MD-NC :  ('can',)
# *-NC :  ('not',)
# NP$-HL :  ("Conant's", "Wright's", "Peabody's", "U.N.'s")
# VBN-NC :  ('broken', 'finished', 'made', 'born', 'Mixed', 'refreshed')
# EX+HVD :  ("There'd",)
# NNS :  ('years', 'people', 'men', 'days', 'members', 'children', 'things', 'others', 'areas', 'problems', 'times', 'words', 'students', 'feet', 'eyes', 'hands', 'schools', 'values', 'lines', 'conditions', 'months', 'costs', 'miles', 'terms', 'minutes', 'countries', 'cases', 'hours', 'forces', 'programs', 'states', 'women', 'ideas', 'methods', 'questions', 'friends', 'services', 'efforts', 'systems', 'groups', 'points', 'results', 'numbers', 'sales', 'ways', 'nations', 'forms', 'persons', 'changes', 'types')
# ) :  (')', ']')
# QL :  ('more', 'as', 'so', 'most', 'very', 'too', 'much', 'quite', 'less', 'no', 'almost', 'far', 'all', 'even', 'rather', 'somewhat', 'little', 'highly', 'right', 'relatively', 'well', 'just', 'fairly', 'completely', 'extremely', 'pretty', 'As', 'really', 'particularly', 'that', 'So', 'All', 'equally', 'entirely', 'slightly', 'nearly', 'sufficiently', 'considerably', 'truly', 'Too', 'purely', 'increasingly', 'Very', 'especially', 'More', 'perfectly', 'still', 'utterly', 'reasonably', 'only')
# AT-HL :  ('the', 'The', 'a', 'A', 'an', 'No', 'An', 'no')
# NNS-TL-HL :  ('Times', 'States', 'Nations', 'Forces', 'Juniors', 'Notes', 'Tests')
# FW-IN+NN :  ("d'etat", "d'identite", "d'hotel")
# PN$ :  ("one's", "anyone's", "somebody's", "everyone's", "everybody's", "someone's", "One's", "anybody's", "Anyone's", "nobody's")
# NR-TL-HL :  ('West', 'Northeast', 'South')
# ,-HL :  (',',)
# WDT+DOD :  ("What'd",)
# PP$ :  ('his', 'their', 'its', 'her', 'our', 'my', 'your', 'His', 'My', 'Their', 'Our', 'Her', 'Its', 'Your', 'thy', 'Thy', 'hys', 'ther', 'myne', 'hir', 'myn', 'thine', 'yore', 'out', 'mine')
# JJ :  ('new', 'such', 'own', 'good', 'great', 'old', 'small', 'American', 'high', 'social', 'important', 'possible', 'long', 'large', 'general', 'different', 'young', 'local', 'human', 'public', 'political', 'available', 'little', 'early', 'economic', 'special', 'big', 'whole', 'major', 'present', 'free', 'necessary', 'national', 'real', 'common', 'open', 'able', 'certain', 'full', 'white', 'true', 'military', 'personal', 'private', 'modern', 'clear', 'short', 'sure', 'strong', 'recent')
# DT+BEZ :  ("That's", "that's")
# HV* :  ("haven't", "Haven't", "ain't")
# FW-PP$ :  ('vos', 'mea', 'mon')
# FW-JJ-TL :  ('Dolce', 'Chemische', 'Generale', 'Grand', 'Francaise', 'Grands', 'Publique', 'Belge', 'Stadtisches', 'Bayerische', 'Invictus', 'Sanctam', 'Nouvelle', 'Allemands', 'Serieuses', 'Douce', 'Platonica', 'Nuovo', 'Sinfonica', 'Centrale', 'Allegro', 'Statistique', 'Populaire', 'Liber', 'Musicale', 'Medicale', 'Schone', 'electriques', 'Populaires', 'Sovietskaya', 'Deutsche', 'National', 'Marocaine', 'Solemnis', 'Scientifique', 'Comique', 'Concertante', 'Indigenes', 'Presto', 'Bonne', 'superieure', 'Buenas', 'Alsatian', 'Philharmonique', 'Siciliana', 'Officielle', 'Royale', 'Democratique', 'Internationale', 'Royaux')
# JJ-NC :  ('friendly', 'sweet', 'Japanese', 'serious', 'young', 'pretty', 'gay', 'incredible', 'using', 'real', 'solemn', 'criminal', 'violent', 'poor', 'true', 'afraid', 'busy', 'false', 'tough', 'wrong', 'reactionary', 'saline', 'approximate', 'dull', 'frivolous', 'deliberate', 'Chinese', 'binomial', 'welcome')
# WRB-TL :  ('Where', 'When')
# VBG-NC :  ('drinking', 'hurting', 'visiting', 'reading', 'looking', 'painting', 'filling')
# WPS-HL :  ('that',)
# WRB+BEZ-TL :  ("Where's",)
# VBN+TO :  ('gotta',)
# RB-TL :  ('Once', 'Out', 'Plus', 'Beyond', 'Away', 'Again', 'Back', 'Forever', 'Down', "O'Clock", 'Really', 'Anywhere', 'Yes', 'Here', 'Backward', 'Well', 'Around', 'Far', 'Somewhere', 'Aside', 'Together', 'Also')
# PPS-NC :  ('it', 'she', 'he')
# JJ-TL-HL :  ('Hon.', 'Federal', 'Medical', 'National', 'New', 'East', 'International', 'Southeast', 'Purple', 'Maritime', 'Dark', 'Bright', 'Rural', 'Confederate', 'Red', 'Free')
# * :  ('not', 'Not', 'nott')
# JJS-TL :  ('Main', 'Chief', 'Paramount', 'Top')
# FW-PPSS :  ('Vous', 'vous', 'Ich')
# BER :  ('are', 'Are', 'art')
# HV-TL :  ('Have',)
# DT+BEZ-NC :  ("that's",)
# VBN-TL-NC :  ('United',)
# FW-WPO :  ('quibusdam',)
# AT-NC :  ('the', 'a', 'an', 'A')
# DO-HL :  ('do',)
# AP-TL :  ('Last', 'Much', 'Other', 'More', 'Latter', 'Same', 'Next')
# DT :  ('this', 'that', 'This', 'each', 'another', 'That', 'Each', 'Another', "'nother")
# WPS+HVZ :  ("that's", "who's")
# PP$-NC :  ('his', 'her', 'our')
# .-HL :  ('.', '?', ':', '!', ';')
# .-NC :  ('?',)
# NR$-TL :  ("South's", "West's", "Today's")
# IN-HL :  ('of', 'in', 'to', 'for', 'on', 'from', 'by', 'with', 'at', 'To', 'For', 'over', 'into', 'without', 'through', 'about', 'On', 'across', 'In', 'unto', 'between', 'under', 'vs.', 'From', 'excluding', 'Out', 'off', 'toward', 'out', 'pro', 'during', 'Of', 'Toward', 'Into', 'Against')
# VBZ-HL :  ('remains', 'Calls', 'Attacks', 'requires', 'Defends', 'loses', 'Intervenes', 'Asks', 'follows', 'Regrets', 'turns', 'Cites', 'saves', 'Decries', 'explains', 'gets', 'meets', 'finds', 'takes', 'Expresses', 'backs', 'Refuses', 'Singles', 'Lives', 'flies', 'lists', 'Disputes', 'throws', 'holds', 'Offers', 'hits', 'replies', 'brings', 'Upholds', 'stands', 'shows', 'Claims', 'Bursts', 'honors', 'Gets', 'moves', 'Questions', 'errs', 'speaks', 'Praises', 'calls', 'visits', 'sings', 'Supports', 'oks')
# FW-RB :  ('deja', 'oui', 'velociter', 'nuper', 'simpliciter', 'semper', 'Sic', 'vielleicht', 'um', 'tout', 'alors', 'Alors', 'cito', 'sic', 'zu', 'despues', 'non', 'olim', 'Forsan', 'domi', 'wiederum')
# RB+BEZ :  ("Here's", "here's", "There's")
# OD :  ('first', 'second', 'third', 'fourth', 'nineteenth', 'First', 'fifth', 'sixth', 'eighteenth', 'ninth', 'eighth', 'seventh', 'Second', 'twentieth', '15th', '20th', 'sixteenth', '18th', 'seventeenth', '19th', '4th', '17th', 'fifteenth', '9th', '13th', '24th', '28th', '23d', 'eighty-sixth', '6th', 'twelfth', 'Third', 'eleventh', '3rd', '29th', 'tenth', '8th', '23rd', 'twenty-first', '30th', '7th', '2nd', '21st', '11th', 'mid-twentieth', '14th', '22nd', 'eighty-fifth', '58th', '31st')
# WPO :  ('that', 'whom', 'Whom', 'who')
# FW-CC-TL :  ('et', 'och', 'Ma')
# FW-AT+NP-TL :  ("L'Astree", "L'Imperiale")
# ---HL :  ('--',)
# WRB+MD :  ("Where'd",)
# WDT+BEZ-NC :  ("what's",)
# PPS+HVD :  ("he'd", "she'd", "She'd", "He'd", "it'd")
# NN$ :  ("man's", "year's", "nation's", "world's", "child's", "mother's", "father's", "patient's", "state's", "city's", "company's", "country's", "husband's", "doctor's", "officer's", "industry's", "town's", "individual's", "earth's", "woman's", "boy's", "latter's", "night's", "wife's", "governor's", "kid's", "week's", "party's", "enemy's", "poet's", "day's", "client's", "girl's", "farmer's", "son's", "club's", "author's", "artist's", "government's", "public's", "life's", "summer's", "university's", "president's", "corporation's", "leader's", "family's", "master's", "clerk's", "bride's")
# VBN-HL :  ('born', 'needed', 'Printed', 'held', 'involved', 'criticized', 'expected', 'estimated', 'Woven', 'Increased', 'raised', 'received', 'Liberated', 'modified', 'subjected', 'knitted', 'set', 'charged', 'proposed', 'fixed', 'repeated', 'cited', 'cleared', 'frozen', 'protected', 'effected', 'vindicated', 'refuted', 'avoided', 'coupled', 'surveyed', 'said', 'portrayed', 'restored', 'asked', 'Urged', 'fragmented', 'consulted', 'pressed', 'Barbecued', 'sighted', 'hailed', 'studied', 'revamped', 'distributed', 'divided', 'established', 'termed', 'summoned', 'perforated')
# ,-TL :  (',',)
# PPSS+BER-N :  ("You're",)
# FW-RB+CC :  ('forisque',)
# BER-HL :  ('are',)
# DTI-HL :  ('any', 'Some', 'some')
# DTI-TL :  ('Any', 'some')
# IN-TL :  ('of', 'Of', 'for', 'In', 'For', 'on', 'To', 'in', 'v.', 'On', 'to', 'With', 'From', '-', 'at', 'Through', 'Between', 'Into', 'Without', 'Over', 'At', 'against', 'About', 'Upon', 'During', 'Like', 'by', 'after', 'After', 'Inside', 'Beyond', 'Towards', 'Before', 'Under')
# AP-NC :  ('few', 'many')
# HVZ-NC :  ('has',)
# VB+IN :  ('Lookit', 'lookit')
# FW-NN$-TL :  ('Dei', "Arte's", 'Curiae')
# NNS$ :  ("children's", "men's", "people's", "women's", "years'", "months'", "states'", "parents'", "artists'", "Respondents'", "ladies'", "farmers'", "workers'", "writers'", "mothers'", "boys'", "engineers'", "janitors'", "prisoners'", "horses'", "manufacturers'", "owners'", "officers'", "members'", "taxpayers'", "students'", "soldiers'", "builders'", "brothers'", "days'", "planters'", "cutters'", "subjects'", "survivors'", "beginners'", "Students'", "bishops'", "stations'", "colonists'", "maskers'", "pounds'", "players'", "poeple's", "composers'", "veterans'", "candidates'", "steelmakers'", "doctors'", "singers'", "masquers'")
# VBG-HL :  ('planning', 'marketing', 'Encouraging', 'Pressing', 'ironing', 'teaching', 'drilling', 'Preserving', 'Meeting', 'Processing', 'computing', 'taxing', 'washing', 'heading', 'feeding', 'consisting', 'cracking', 'rotating', 'Underlying', 'Weaving', 'handling', 'impending', 'assisting', 'Boating', 'straightening', 'Selecting', 'melting', 'Achieving', 'Remaking', 'increasing', 'Staining', 'Adjoining', 'filing', 'selecting', 'Getting', 'lacking', 'Taxing', 'Betting', 'acting', 'joining', 'revolving', 'farming', 'Lighting', 'Pulling', 'fattening', 'cleaning', 'Helping', 'Hunting', 'Mailing', 'distributing')
# FW-NPS :  ('Atlantes', 'Dieux')
# CD-HL :  ('2', '1', '3', '4', '5', '6', '7', '9', '17', '8', '10', '11', '24', 'Two', "'61", '18', '14', '12', 'Four', '13', '15', 'one', 'Five', '19', 'seven', 'three', 'Six', '1861', 'Three', '2.4', '26', 'fourteen', '2-5', 'six', '5.3', 'five', '8,280', '16', '1,500', '5.4', '7-1', '2.1', '1954', 'octillion', '21', '1791', '1961', '2-3', 'Thirty-four', '30')
# PP$-TL :  ('Our', 'Your', 'My', 'Their', 'Its')
# VB-TL :  ('Define', 'Come', 'Hail', 'Sing', 'Get', 'Go', 'Ask', 'Hark', 'Traverse', 'Strike', 'Join', 'Ride', 'Live', 'Stay', 'Study', 'Pass', 'Need', 'Keep', 'Feed', 'Fire', 'Rise', 'Advise', 'Tan', 'Ramble', 'Buy', 'Lend', 'Awake', 'Listen', 'Balkanize', 'Eat', 'Strut', 'Abide', 'Swim', 'Seize', 'Crumble', 'Explain', 'Assist', 'File', 'Sail', 'Weep', 'Send', 'Love', 'Succeed', 'Equate', 'Ring', 'Step', 'Wander', 'Risk', 'Consent', 'Learn')
# VBN-TL :  ('United', 'Armed', 'Inc.', 'Allied', 'Adjusted', 'Ltd.', 'Illustrated', 'Associated', 'Got', 'Handicapped', 'Reformed', 'Diversified', 'Planned', 'Revised', 'Poised', 'Limited', 'Distilled', 'Neglected', 'Scared', 'Gone', 'Built', 'Forgotten', 'Collected', 'Confuted', 'Crippled', 'Mounted', 'Consolidated', 'Spoken', 'Syndicated', 'Combined', 'Foamed', 'Revisited', 'Elevated', 'Printed', 'Blessed', 'Burnt', 'Folded', 'Accepted', 'Stricken', 'Fallen', 'Superposed', 'Born', 'Set')
# VBZ :  ('seems', 'says', 'makes', 'comes', 'gives', 'becomes', 'means', 'knows', 'appears', 'provides', 'takes', 'goes', 'follows', 'shows', 'remains', 'looks', 'gets', 'needs', 'finds', 'begins', 'wants', 'requires', 'depends', 'includes', 'stands', 'calls', 'consists', 'offers', 'feels', 'believes', 'continues', 'indicates', 'exists', 'represents', 'involves', 'lies', 'writes', 'holds', 'contains', 'brings', 'serves', 'happens', 'tends', 'uses', 'sees', 'meets', 'works', 'tells', 'leads', 'suggests')
# DOZ*-TL :  ("Doesn't",)
# FW-DT :  ('hoc',)
# WP$ :  ('whose', 'Whosever', 'Whose')
# FW-NNS-NC :  ('Sabinas', 'enquetes')
# RB :  ('only', 'also', 'now', 'then', 'even', 'well', 'still', 'never', 'back', 'just', 'about', 'here', 'so', 'again', 'always', 'there', 'often', 'away', 'once', 'however', 'first', 'ever', 'Then', 'far', 'together', 'already', 'ago', 'too', 'almost', 'probably', 'long', 'perhaps', 'usually', 'Now', 'yet', 'Thus', 'really', 'around', 'therefore', 'Even', 'much', 'because', 'sometimes', 'However', 'alone', 'soon', 'simply', 'thus', 'especially', 'Here')
# FW-NR-TL :  ('morgen', 'heute')
# WPS+BEZ-NC :  ("who's",)
# NP-TL :  ('York', 'Rhode', 'America', 'England', 'U.S.', 'John', 'Providence', 'Brown', 'S.', 'Orleans', 'U.', 'Berlin', 'God', 'Washington', 'Chicago', 'Manchester', 'Europe', 'Sharpe', 'India', 'Greenwich', 'California', 'Congress', 'Utopia', 'Jersey', 'Germany', 'Carolina', 'Carleton', 'Texas', 'Brooklyn', 'Columbia', 'Asia', 'Britain', 'Georgia', 'Saxon', 'Pennsylvania', 'Massachusetts', 'Africa', 'Philadelphia', 'Dallas', 'Beowulf', 'Soviet', 'Hans', 'Harvard', 'Louis', 'A', 'Bible', 'Illinois', 'Virginia', 'Kansas', 'St.')
# FW-NN-TL-NC :  ('Domina',)
# DO*-HL :  ("Don't",)
# JJT :  ('best', 'greatest', 'highest', 'largest', 'latest', 'worst', 'earliest', 'biggest', 'strongest', 'finest', 'smallest', 'nearest', 'newest', 'oldest', 'lowest', 'slightest', 'deepest', 'youngest', 'closest', 'simplest', 'hardest', 'easiest', 'longest', 'richest', 'noblest', 'fastest', 'fullest', 'Best', 'Newest', 'coolest', 'barest', 'hottest', 'eldest', 'staunchest', 'poorest', 'loveliest', 'weakest', 'widest', 'happiest', 'loudest', 'safest', 'dearest', 'Biggest', 'strictest', 'purest', 'worthiest', 'bitterest', 'deadliest', 'farthest', 'merest')
# NN+BEZ-TL :  ("Pa's",)
# NN+MD :  ("cowhand'd",)
# FW-DTS :  ('haec',)
# BEZ-HL :  ('is', 'Is')
# PPO-NC :  ('him', 'you', 'it')
# RB+BEZ-HL :  ("Here's",)
# FW-CS :  ('bevor', 'quam')
# VBN-TL-HL :  ('United', 'Armed')
# NPS-HL :  ('Filipinos', 'Bucs', 'Republicans', 'Russians', 'Soviets', 'Negroes', 'Indians', 'Terpers')
# WQL :  ('how', 'How', 'however', 'However')
# WPO-TL :  ('What', 'Whom')
# JJR-TL :  ('Greater', 'Higher', 'Better', 'Lower', 'Younger', 'Elder')
# PPS-TL :  ('It', 'He')
# FW-BER :  ('sind', 'sunt', 'etes')
# JJ-HL :  ('new', 'New', 'physical', 'General', 'Experimental', 'small', 'necessary', 'special', 'Basic', 'Industrial', 'big', 'good', 'Atomic', 'personal', 'American', 'electronic', 'primary', 'complete', 'photochemical', 'Federal', 'spiritual', 'Special', 'dead', 'Hot', 'restorative', 'Social', 'general', 'Fiscal', 'indirect', 'short', 'Local', 'Additional', 'Theoretical', 'cylindrical', 'binomial', 'total', 'Direct', 'Simple', 'neutral', 'educational', 'thyroid-stimulating', 'due', 'Financial', 'natural', 'modest', 'individual', 'over-all', 'Military', 'green', 'current')
# JJ-TL :  ('New', 'National', 'Federal', 'American', 'Southern', 'Western', 'East', 'North', 'West', 'White', 'General', 'South', 'Democratic', 'Old', 'Great', 'Red', 'Civil', 'Central', 'Medical', 'Junior', 'International', 'Big', 'Public', 'Supreme', 'High', 'Holy', 'Blue', 'Little', 'Industrial', 'Northern', 'Middle', 'Daily', 'Pacific', 'Presidential', 'Eastern', 'Economic', 'Foreign', 'Royal', 'Roman', 'Long', 'Black', 'Geometric', 'British', 'Memorial', 'Latin', 'Vice', 'Christian', 'Superior', 'Southeast', 'Social')
# NNS$-HL :  ("Beginners'", "Sixties'", "Dealers'", "Idols'")
# `` :  ('``',)
# PPS-HL :  ('it', 'He')
# NP$-TL :  ("Christ's", "Hudson's", "Peter's", "York's", "Harper's", "John's", "Lord's", "Patrick's", "Mary's", 'Harpers', "Salyer's", "Mexico's", "Kaiser's", "Sharpe's", "Sanford's", "Jehovah's", "Lovejoy's", "Scotty's", "Michael's", "Lloyd's", "Cav's", "Graves'", "Loew's", "Django's", "Way's", "Pickett's", "Manley's", "California's", "Canaveral's", "David's", "Woodman's", "Hector's", "Nam's", "Leningrad's", "Jersey's", "Stephen's", "Martin's", "Blanchard's", "Luke's", "McSorley's", "McGovern's", "Sarum's", "Thayer's", "Verplanck's", "Martha's", "Satan's", "Chicago's", "Carnarvon's", "Anne's", "Bernadine's")
# CS-HL :  ('as', 'If', 'because', 'if', 'while', 'than', 'before', 'that')
# RP-HL :  ('up', 'off', 'out', 'in', 'over', 'down')
# CS-NC :  ('than', 'that', 'unless')
# JJR-NC :  ('stranger', 'smaller', 'Calmer', 'friendlier')
# AP-HL :  ('other', 'More', 'Other', 'more', 'Many', 'next', 'much', 'less', 'single', 'only', 'same', 'enough', 'Present', 'many', 'Little', 'Less', 'fewer', 'last', 'Most')
# FW-PPL+VBZ :  ("s'accuse", "s'excuse")
# BE-TL :  ('Be',)
# PPS+MD :  ("he'd", "she'd", "He'll", "he'll", "She'd", "He'd", "It'll", "it'll", "She'll", "it'd", "she'll")
# NP-NC :  ('George', 'Mary', 'Jack', 'Garryowen', 'Martinique', 'Buckman', 'Chinese')
# DT-NC :  ('that', 'this')
# WPS+BEZ-TL :  ("Who's",)
# RB-NC :  ('here', 'no', 'then', 'now', 'emotionally', 'rarely', 'yes', 'importunately', 'Yes', 'perhaps', 'too', 'out')
# MD+TO :  ('oughta',)
# NP-TL-HL :  ('Rhode', 'Congress', 'House')
# NN+HVZ :  ("guy's",)
# DO-NC :  ('do',)
# AT-TL-HL :  ('A', 'the')
# FW-IN+NP-TL :  ("d'Yquem",)
# BEZ :  ('is', 'Is', 'ys')
# CD :  ('one', 'two', 'three', '1', 'four', 'One', '2', 'five', 'million', '3', '1960', 'six', 'hundred', '1961', '4', '10', 'ten', '30', '15', '1959', '1958', '20', '5', 'eight', 'thousand', '8', '25', '100', 'Two', 'seven', '12', '6', 'nine', 'billion', 'twenty', '11', '50', 'fifty', '16', '1957', '14', '18', '21', '1954', '7', '60', 'thirty', '22', '23', 'twelve')
# PP$$ :  ('mine', 'ours', 'his', 'theirs', 'hers', 'yours', 'Theirs', 'Ours', 'His', 'Yours', "their's")
# DO :  ('do', 'Do', 'doo', 'dost')
# WRB :  ('when', 'where', 'When', 'how', 'why', 'Why', 'How', 'however', 'Where', 'whenever', 'wherever', 'However', 'whereby', 'Whenever', 'whereof', 'wherein', 'Wherever', 'whence', 'howe', 'whereever', 'wheare', 'Whence', 'wher', 'whereon', 'wherewith', 'Wherefore')
# FW-VB :  ('vade', 'dites', 'faciunt', 'esse', 'tangere', 'gosaimasu', 'duces', 'iuvabit', 'meminisse', "Mach't", 'Vive', 'nolo', 'Fermate', 'voulez', 'noli', 'Habla')
# WDT :  ('which', 'what', 'What', 'whatever', 'Whatever', 'Which', 'whichever')
# MD+PPSS :  ('willya',)
# BEM* :  ("ain't",)
# NR$ :  ("today's", "Sunday's", "yesterday's", "Today's", "tomorrow's", "Monday's", "Saturday's", "Friday's", "tonight's", "Thursday's", "Tuesday's", "Wednesday's")
# MD :  ('would', 'will', 'can', 'may', 'could', 'must', 'should', 'might', 'shall', 'ought', 'need', 'Would', 'Can', 'Will', 'Should', 'Could', 'May', 'Shall', 'dare', 'Must', 'shuld', 'colde', 'maye', 'Ought', 'mayst', 'wil', 'wold', 'mai', 'wilt', 'shulde', 'kin', 'wolde', 'wod')
# NP+BEZ :  ("Mahzeer's", "Ike's", "W.'s", "Kate's", "Katharine's", "Arthur's", "Black's")
# PN-NC :  ('one', 'everybody')
# PPO-HL :  ('us', 'them', 'it', 'you')
# FW-VBD-TL :  ('Stabat',)
# DOZ* :  ("doesn't", "don't", "Doesn't")
# JJR+CS :  ("lighter'n",)
# WPS+MD :  ("who'd", "that'd", "Who'd", "Who'll")
# PPSS :  ('I', 'they', 'we', 'you', 'They', 'We', 'You', 'ye', 'thou', 'yow', 'ya', 'Thou', "Y'all", 'wee', 'thei', 'dey', "you'uns", "H'all", 'Thay')
# PN+BEZ :  ("Everything's", "Nothing's", "Somebody's", "everything's")
# VBD-NC :  ('came', 'wrote', 'looked', 'knew', 'wanted', 'put')
# WPS-TL :  ('What', 'Who', 'That')
# NP+BEZ-NC :  ("Mack's", "Jack's")
# PPL-HL :  ('himself',)
# NN+NN-NC :  ('stomach-belly',)
# RBR :  ('later', 'more', 'longer', 'better', 'further', 'earlier', 'Later', 'closer', 'farther', 'less', 'Further', 'higher', 'harder', 'faster', 'sooner', 'deeper', 'lower', 'easier', 'nearer', 'Earlier', 'Better', 'More', 'slower', 'louder', 'worse', 'cheaper', 'Closer', 'tighter', 'oftener', 'tougher')
# RB-HL :  ('approximately', 'Here', 'First', 'abroad', 'there', 'again', 'also', 'fast', 'quick', 'Long', 'ahead', 'wild', 'near', 'Mostly', 'along', 'now', 'Back', 'too', 'fully', 'Actively', 'Somewhere', 'spiritually', 'generally', 'back', 'here', 'e.g.', 'regularly', 'electronically', 'Now', 'together', 'then', 'Gradually')
# QLP :  ('enough', 'indeed', "'nuff", 'Indeed', 'still')
# BER-NC :  ('are',)
# (-HL :  ('(',)
# PN+MD :  ("anybody'd", "Someone'll", "Somebody'll")
# WPS-NC :  ('that',)
# JJ+JJ-NC :  ('big-large', 'long-far')
# WRB+DOD :  ("Where'd",)
# ABN-HL :  ('All', 'all')
# NN$-HL :  ("Drug's", "industry's", "Navy's", "drug's", "Golf's", "amendment's")
# JJT-TL :  ('Highest', 'Greatest', 'Youngest')
# NN-TL-NC :  ('State',)
# DOZ-TL :  ('Does',)
# NNS$-NC :  ("sisters'",)
# BER*-NC :  ("aren't",)
# FW-UH :  ('adieu', 'bien', 'Bonjour', 'Arigato')
# PPO-TL :  ('Me', 'It', 'You', 'Him', 'Us')
# OD-NC :  ('first',)
# QL-TL :  ('Most', 'Especially', 'So', 'Almost', 'Too')
# ABX :  ('both', 'Both')
